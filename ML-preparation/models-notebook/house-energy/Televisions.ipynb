# %%
# Import Library
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pickle
import os

# Read Dataset
url = "https://raw.githubusercontent.com/josgiv/home-appliance-dataset/master/Televisions.csv"
df = pd.read_csv(url)

df
# Out:
#      ENERGY STAR Unique ID            ENERGY STAR Partner Brand Name  \
# 0                  3049373           LG Electronics, Inc.         LG
# 1                  2838654           LG Electronics, Inc.         LG
# 2                  3049374           LG Electronics, Inc.         LG
# 3                  2838655           LG Electronics, Inc.         LG
# 4                  3143234           LG Electronics, Inc.         LG
# ..                     ...                            ...        ...
# 104                3354310  Samsung Electronics Co., Ltd.    Samsung
# 105                2406405  Samsung Electronics Co., Ltd.    Samsung
# 106                3354428  Samsung Electronics Co., Ltd.    Samsung
# 107                2406379  Samsung Electronics Co., Ltd.    Samsung
# 108                2406517  Samsung Electronics Co., Ltd.    Samsung
#
#       Model Name Model Number  \
# 0    OLED55B4PU*  OLED55B4PU*
# 1    OLED55C4PU*  OLED55C4PU*
# 2    OLED65B4PU*  OLED65B4PU*
# 3    OLED65C4PU*  OLED65C4PU*
# 4    OLED77B4PU*  OLED77B4PU*
# ..           ...          ...
# 104   QN55S90DAF   QN55S90DAF
# 105   QN55S95CAF   QN55S95CAF
# 106   QN55S95DAF   QN55S95DAF
# 107  QN65QN85CAF  QN65QN85CAF
# 108  QN65QN90CAF  QN65QN90CAF
#
#                           Additional Model Information  \
# 0    OLED55B4AU*,OLED55B4AU*,OLED55B4AU* is the sam...
# 1    OLED55C4AU*,OLED55C4AU*,OLED55C4AU* is the sam...
# 2    OLED65B4AU*,OLED65B4AU*,OLED65B4AU* is the sam...
# 3    OLED65C4AU*,OLED65C4AU*,OLED65C4AU* is the sam...
# 4    OLED77B4AU*,OLED77B4AU*,OLED77B4AU* is the sam...
# ..                                                 ...
# 104  QN55S90DDF,QN55S90DDF,Same as basic model exce...
# 105  QN55S95CDF,QN55S95CDF,Same as basic model exce...
# 106  QN55S95DDF,QN55S95DDF,Same as basic model exce...
# 107  QN65QN85CDF,QN65QN85CDF,Same as basic model ex...
# 108  QN65QN90CDF,QN65QN90CDF,Same as basic model ex...
#
#                            UPC     Product Type Application   Display Type  \
# 0    195174077290;195174077306  Television (TV)    Consumer           OLED
# 1    195174077238;195174078150  Television (TV)    Consumer           OLED
# 2    195174077252;195174078174  Television (TV)    Consumer           OLED
# 3    195174077207;195174078181  Television (TV)    Consumer           OLED
# 4    195174077214;195174077221  Television (TV)    Consumer           OLED
# ..                         ...              ...         ...            ...
# 104                        NaN  Television (TV)    Consumer           OLED
# 105                        NaN  Television (TV)    Consumer          Other
# 106                        NaN  Television (TV)    Consumer           OLED
# 107                        NaN  Television (TV)    Consumer  QD-LED (QLED)
# 108                        NaN  Television (TV)    Consumer  QD-LED (QLED)
#
#      ... Reported On Mode Power (per the Federal Test Procedure) (watts)  \
# 0    ...                                              95.50
# 1    ...                                             103.10
# 2    ...                                             114.00
# 3    ...                                             131.90
# 4    ...                                             142.80
# ..   ...                                                ...
# 104  ...                                              98.58
# 105  ...                                             100.00
# 106  ...                                             112.43
# 107  ...                                             110.86
# 108  ...                                              83.00
#
#      Reported Annual Energy Consumption (kWh)  \
# 0                                       177.0
# 1                                       191.0
# 2                                       211.0
# 3                                       244.0
# 4                                       263.0
# ..                                        ...
# 104                                     184.1
# 105                                     192.9
# 106                                     245.8
# 107                                     160.1
# 108                                     161.9
#
#      Measured Standby Mode Power (Watts)  \
# 0                                    0.4
# 1                                    NaN
# 2                                    0.4
# 3                                    NaN
# 4                                    0.4
# ..                                   ...
# 104                                  NaN
# 105                                  NaN
# 106                                  NaN
# 107                                  NaN
# 108                                  NaN
#
#      Power Consumption in Standby Mode when Not Connected to a Network (watts)  \
# 0                                                  0.3
# 1                                                  0.3
# 2                                                  0.3
# 3                                                  0.3
# 4                                                  0.3
# ..                                                 ...
# 104                                                0.3
# 105                                                0.3
# 106                                                0.3
# 107                                                0.3
# 108                                                0.3
#
#      Power Consumption in Standby Mode when Connected to a Network (watts)  \
# 0                                                  0.4
# 1                                                  0.4
# 2                                                  0.4
# 3                                                  0.5
# 4                                                  0.4
# ..                                                 ...
# 104                                                0.6
# 105                                                0.4
# 106                                                0.7
# 107                                                0.4
# 108                                                0.4
#
#     Reported Standby-Active, Low Mode Power (watts) Date Available On Market  \
# 0                                               0.4               02/20/2024
# 1                                               0.4               02/20/2024
# 2                                               0.4               04/07/2024
# 3                                               0.5               02/20/2024
# 4                                               0.4               04/07/2024
# ..                                              ...                      ...
# 104                                             NaN               12/29/2023
# 105                                             0.4               02/10/2023
# 106                                             NaN               01/02/2024
# 107                                             0.3               12/31/2022
# 108                                             0.3               12/31/2022
#
#     Date Certified        Markets  \
# 0       12/19/2023  United States
# 1       12/05/2023  United States
# 2       12/20/2023  United States
# 3       12/05/2023  United States
# 4       12/21/2023  United States
# ..             ...            ...
# 104     12/18/2023  United States
# 105     12/29/2022  United States
# 106     12/26/2023  United States
# 107     12/28/2022  United States
# 108     01/05/2023  United States
#
#                                 CB Model Identifier
# 0    ES_1118034_OLED55B4PU*_121920231333329_5810272
# 1    ES_1118034_OLED55C4PU*_120520230754834_6379453
# 2    ES_1118034_OLED65B4PU*_122020231113408_7049302
# 3    ES_1118034_OLED65C4PU*_120520231442163_1126459
# 4    ES_1118034_OLED77B4PU*_122120230719523_8888606
# ..                                              ...
# 104   ES_1023593_QN55S90DAF_121820230432730_2283422
# 105   ES_1023593_QN55S95CAF_123020220352905_3086937
# 106   ES_1023593_QN55S95DAF_122620230523739_4325753
# 107  ES_1023593_QN65QN85CAF_122820220822846_3841384
# 108  ES_1023593_QN65QN90CAF_010620230452315_1797267
#
# [109 rows x 35 columns]

# %%
print(df.columns)
# Out:
# Index(['ENERGY STAR Unique ID', 'ENERGY STAR Partner', 'Brand Name',
#        'Model Name', 'Model Number', 'Additional Model Information', 'UPC',
#        'Product Type', 'Application', 'Display Type',
#        'Backlight Technology Type', 'Diagonal Viewable Screen Size (in.)',
#        'Screen Area (sq. in.)', 'Native Horizontal Resolution (pixels)',
#        'Native Vertical Resolution (pixels)', 'Resolution Format',
#        'High Contrast Ratio (HCR) Display', 'Physical Data Ports Available',
#        'Ethernet Supported', 'Low Power Wireless Technologies Supported',
#        'Features', 'Automatic Brightness Control',
#        'Is Automatic Brightness Control Enabled by Default in the Default SDR Preset Picture Setting When Television is Shipped?',
#        'Average On Mode Power Consumption for Certification (watts)',
#        'Maximum Average On Mode Power for Certification (watts)',
#        'Reported On Mode Power (per the Federal Test Procedure) (watts)',
#        'Reported Annual Energy Consumption (kWh)',
#        'Measured Standby Mode Power (Watts)',
#        'Power Consumption in Standby Mode when Not Connected to a Network (watts)',
#        'Power Consumption in Standby Mode when Connected to a Network (watts)',
#        'Reported Standby-Active, Low Mode Power (watts)',
#        'Date Available On Market', 'Date Certified', 'Markets',
#        'CB Model Identifier'],
#       dtype='object')

# %%
irrelevant_features = [
    'ENERGY STAR Unique ID',
    'ENERGY STAR Partner',
    'UPC',
    'Native Horizontal Resolution (pixels)',
    'Native Vertical Resolution (pixels)',
    'Date Available On Market',
    'Date Certified',
    'Model Name',
    'Model Number',
    'Additional Model Information',
    'Product Type',
    'CB Model Identifier',
    'Markets',
    'Application',
    'Screen Area (sq. in.)',
    'Reported On Mode Power (per the Federal Test Procedure) (watts)',
    'Power Consumption in Standby Mode when Not Connected to a Network (watts)',
    'Power Consumption in Standby Mode when Connected to a Network (watts)',
    'Reported Standby-Active, Low Mode Power (watts)',
    'Measured Standby Mode Power (Watts)',       
    'Average On Mode Power Consumption for Certification (watts)',
    'Maximum Average On Mode Power for Certification (watts)',
    
    ]



# Menghapus fitur-fitur yang tidak relevan


df = df.drop(columns=irrelevant_features)

# %%
# Ubah nama kolom
df.rename(columns={
    'Is Automatic Brightness Control Enabled by Default in the Default SDR Preset Picture Setting When Television is Shipped?': 'Auto Brightness'
}, inplace=True)

df
# Out:
#     Brand Name   Display Type Backlight Technology Type  \
# 0           LG           OLED                      OLED
# 1           LG           OLED                      OLED
# 2           LG           OLED                      OLED
# 3           LG           OLED                      OLED
# 4           LG           OLED                      OLED
# ..         ...            ...                       ...
# 104    Samsung           OLED                      OLED
# 105    Samsung          Other                      OLED
# 106    Samsung           OLED                      OLED
# 107    Samsung  QD-LED (QLED)            Direct-lit LED
# 108    Samsung  QD-LED (QLED)            Direct-lit LED
#
#      Diagonal Viewable Screen Size (in.) Resolution Format  \
# 0                                   54.6          4K (UHD)
# 1                                   54.6          4K (UHD)
# 2                                   64.5          4K (UHD)
# 3                                   64.5          4K (UHD)
# 4                                   76.7          4K (UHD)
# ..                                   ...               ...
# 104                                 54.6          4K (UHD)
# 105                                 54.6          4K (UHD)
# 106                                 54.6          4K (UHD)
# 107                                 64.5          4K (UHD)
# 108                                 64.5          4K (UHD)
#
#     High Contrast Ratio (HCR) Display  \
# 0                                 Yes
# 1                                 Yes
# 2                                 Yes
# 3                                 Yes
# 4                                 Yes
# ..                                ...
# 104                               Yes
# 105                               Yes
# 106                               Yes
# 107                                No
# 108                                No
#
#                     Physical Data Ports Available          Ethernet Supported  \
# 0    Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 1    Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 2    Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 3    Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 4    Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# ..                                            ...                         ...
# 104  Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 105  Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 106  Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 107  Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
# 108  Universal Serial Bus (USB),Other,RS-232,HDMI  Fast Ethernet (100 Mbit/s)
#
#     Low Power Wireless Technologies Supported  \
# 0                                   Bluetooth
# 1                                   Bluetooth
# 2                                   Bluetooth
# 3                                   Bluetooth
# 4                                   Bluetooth
# ..                                        ...
# 104                                 Bluetooth
# 105                                 Bluetooth
# 106                                 Bluetooth
# 107                                 Bluetooth
# 108                                 Bluetooth
#
#                                               Features  \
# 0    Quick Start,Wake-On-Cast Compatibility,Control...
# 1    Quick Start,Wake-On-Cast Compatibility,Control...
# 2    Quick Start,Wake-On-Cast Compatibility,Control...
# 3    Quick Start,Wake-On-Cast Compatibility,Control...
# 4    Quick Start,Wake-On-Cast Compatibility,Control...
# ..                                                 ...
# 104  High Dynamic Range Upscaling,Wake-On-Cast Comp...
# 105  Wake-On-Cast Compatibility,Other,Control Via S...
# 106  High Dynamic Range Upscaling,Wake-On-Cast Comp...
# 107  Control Via Smart Speaker,Motion-based Dynamic...
# 108  Control Via Smart Speaker,Motion-based Dynamic...
#
#     Automatic Brightness Control Auto Brightness  \
# 0                            Yes              No
# 1                            Yes              No
# 2                            Yes              No
# 3                            Yes              No
# 4                            Yes              No
# ..                           ...             ...
# 104                          Yes              No
# 105                          Yes              No
# 106                          Yes              No
# 107                          Yes              No
# 108                          Yes              No
#
#      Reported Annual Energy Consumption (kWh)
# 0                                       177.0
# 1                                       191.0
# 2                                       211.0
# 3                                       244.0
# 4                                       263.0
# ..                                        ...
# 104                                     184.1
# 105                                     192.9
# 106                                     245.8
# 107                                     160.1
# 108                                     161.9
#
# [109 rows x 13 columns]

# %%
print(df.columns)
# Out:
# Index(['Brand Name', 'Display Type', 'Backlight Technology Type',
#        'Diagonal Viewable Screen Size (in.)', 'Resolution Format',
#        'High Contrast Ratio (HCR) Display', 'Physical Data Ports Available',
#        'Ethernet Supported', 'Low Power Wireless Technologies Supported',
#        'Features', 'Automatic Brightness Control', 'Auto Brightness',
#        'Reported Annual Energy Consumption (kWh)'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Dataframe df sudah ada di sini

# Memisahkan kolom numerik dan kategorikal
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()
categorical_cols = df.select_dtypes(exclude=['number']).columns.tolist()

# Terapkan StandardScaler pada kolom numerik
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Label Encoding untuk kolom kategorikal
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

print(df.head())
# Out:
#    Brand Name  Display Type  Backlight Technology Type  \
# 0           4             2                          2
# 1           4             2                          2
# 2           4             2                          2
# 3           4             2                          2
# 4           4             2                          2
#
#    Diagonal Viewable Screen Size (in.)  Resolution Format  \
# 0                            -0.005566                  0
# 1                            -0.005566                  0
# 2                             0.521315                  0
# 3                             0.521315                  0
# 4                             1.170603                  0
#
#    High Contrast Ratio (HCR) Display  Physical Data Ports Available  \
# 0                                  1                              4
# 1                                  1                              4
# 2                                  1                              4
# 3                                  1                              4
# 4                                  1                              4
#
#    Ethernet Supported  Low Power Wireless Technologies Supported  Features  \
# 0                   0                                          0         5
# 1                   0                                          0         5
# 2                   0                                          0         5
# 3                   0                                          0         5
# 4                   0                                          0         5
#
#    Automatic Brightness Control  Auto Brightness  \
# 0                             1                0
# 1                             1                0
# 2                             1                0
# 3                             1                0
# 4                             1                0
#
#    Reported Annual Energy Consumption (kWh)
# 0                                  0.082812
# 1                                  0.236707
# 2                                  0.456557
# 3                                  0.819310
# 4                                  1.028167

# %%
# Loop melalui setiap kolom di DataFrame 'df'
print(f"DataFrame:")
for col in df.columns:
    unique_values = df[col].unique()
    print(f"Kolom '{col}': {unique_values}")
print("\n")
# Out:
# DataFrame:
# Kolom 'Brand Name': [ 4  0  1  5 10  3  7 11  8  2 12  6 13  9]
# Kolom 'Display Type': [2 0 1 3 4]
# Kolom 'Backlight Technology Type': [2 0 1 3]
# Kolom 'Diagonal Viewable Screen Size (in.)': [-0.00556616  0.52131496  1.17060281  1.47928063 -2.2072906  -2.2062262
#  -2.08381947 -2.0880771  -1.92735175 -1.22963341 -0.64953198  0.01572196
#  -0.70275229 -0.3834304  -0.27698977 -1.65912136 -1.23495544 -1.23655205
#  -1.20834529 -0.27113553 -0.78258276  0.51599293  1.04659947 -1.63410781
#   1.5910433  -1.65805695 -0.80919292  1.05351811  1.64426361 -0.69743026
#   1.05884014 -0.00343735  0.52291157 -0.01088819  0.14877275  0.17538291
#   0.54792512  1.16528077  1.21317906  1.58572126 -1.23442324 -0.25037961]
# Kolom 'Resolution Format': [0 2 1 3]
# Kolom 'High Contrast Ratio (HCR) Display': [1 0]
# Kolom 'Physical Data Ports Available': [4 3 2 1 0]
# Kolom 'Ethernet Supported': [0 4 2 3 1]
# Kolom 'Low Power Wireless Technologies Supported': [0 2 1]
# Kolom 'Features': [ 5  6 13  4  8  1  3  9  7 12  2 10  0 11]
# Kolom 'Automatic Brightness Control': [1 0]
# Kolom 'Auto Brightness': [0 1]
# Kolom 'Reported Annual Energy Consumption (kWh)': [ 0.0828119   0.23670699  0.45655711  0.81930983  1.02816745  1.47886021
#   2.11642558 -1.66103932 -1.62003727 -1.64334139 -1.59585376 -1.5035167
#  -1.24145535 -0.77350435 -0.51078345  0.32464704 -0.41185089 -0.64489203
#  -0.28433782 -0.20299327 -0.40415614 -0.92300244  0.52108313 -1.36600045
#  -1.26926639 -1.12427523 -1.34621394 -0.46747298 -1.15054732 -0.7719654
#  -0.38052225  0.72521397  1.14336891 -1.36819895  1.95219754 -1.35720644
#  -1.42865774 -1.43415399 -1.1153713  -1.04315054 -0.02953152 -0.36788087
#   0.29166952 -0.30192583  0.41258709  0.51151965  0.99518993  0.9512199
#   1.50084522  1.87459044 -0.15902325  1.06004572  0.03664337  1.16007752
#   0.89735662  0.55878742  1.18096329  0.15756094  1.52151113  0.39829683
#  -0.19134121  0.18317348 -0.71909145 -0.83825022 -0.75987365 -0.60806713
#  -0.50165967 -0.41338984 -0.2110178  -0.43647411 -0.21178728 -0.11043637
#   0.06907126  0.18658116 -1.1552741  -0.15649497  0.18339333  0.22263658
#   1.50139485  1.66243507  1.24801758  1.41180592  1.40081341  2.10323457
#   0.25759275  0.61924621  2.42421576  0.63903272  2.68473816 -1.20594956
#  -0.41262037 -0.04360193 -0.30412433  0.59836045 -0.04909818  0.16085869
#   0.83909634 -0.10296146 -0.08317495]

# %%
# Memisahkan fitur (X) dan label (y)
X = df.drop(columns=['Reported Annual Energy Consumption (kWh)'])
y = df['Reported Annual Energy Consumption (kWh)']

# Pembagian dataset menjadi data training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Tampilkan ukuran data train dan test
print(f"Ukuran data train: {X_train.shape}, {y_train.shape}")
print(f"Ukuran data test: {X_test.shape}, {y_test.shape}")
# Out:
# Ukuran data train: (98, 12), (98,)
# Ukuran data test: (11, 12), (11,)

# %%
df.columns
# Out:
# Index(['Brand Name', 'Display Type', 'Backlight Technology Type',
#        'Diagonal Viewable Screen Size (in.)', 'Resolution Format',
#        'High Contrast Ratio (HCR) Display', 'Physical Data Ports Available',
#        'Ethernet Supported', 'Low Power Wireless Technologies Supported',
#        'Features', 'Automatic Brightness Control', 'Auto Brightness',
#        'Reported Annual Energy Consumption (kWh)'],
#       dtype='object')

# %%
# Inisialisasi model Decision Tree Regressor
dt_regressor = DecisionTreeRegressor(random_state=42)

# Melatih model Decision Tree Regressor
dt_regressor.fit(X_train, y_train)

# Prediksi dengan model yang dilatih
y_pred_dt = dt_regressor.predict(X_test)

# Evaluasi model Decision Tree Regressor
mse_dt = mean_squared_error(y_test, y_pred_dt)
r2_dt = r2_score(y_test, y_pred_dt)

# Menyimpan hasil evaluasi ke dalam DataFrame
dt_regression_results = pd.DataFrame({
    "Model": ["Decision Tree Regressor"],
    "Mean Squared Error": [mse_dt],
    "R^2 Score": [r2_dt],
})

# Menampilkan hasil evaluasi regresi
print("\n", dt_regression_results)
# Out:
#                       Model  Mean Squared Error  R^2 Score
# 0  Decision Tree Regressor            0.078279   0.942563

# %%
# Inisialisasi model Random Forest Regressor
rf_regressor = RandomForestRegressor(random_state=42)

# Melatih model Random Forest Regressor
rf_regressor.fit(X_train, y_train)

# Prediksi dengan model yang dilatih
y_pred_rf = rf_regressor.predict(X_test)

# Evaluasi model Random Forest Regressor
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# Menyimpan hasil evaluasi ke dalam DataFrame
rf_regression_results = pd.DataFrame({
    "Model": ["Random Forest Regressor"],
    "Mean Squared Error": [mse_rf],
    "R^2 Score": [r2_rf],
})

# Menampilkan hasil evaluasi regresi
print("\n", rf_regression_results)
# Out:
#                       Model  Mean Squared Error  R^2 Score
# 0  Random Forest Regressor            0.099293   0.927143

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Inisialisasi model HistGradientBoostingRegressor
hgb_regressor = HistGradientBoostingRegressor()

# Melatih model HistGradientBoostingRegressor
hgb_regressor.fit(X_train, y_train)

# Prediksi dengan model yang dilatih
y_pred_hgb = hgb_regressor.predict(X_test)

# Evaluasi model HistGradientBoostingRegressor
mse_hgb = mean_squared_error(y_test, y_pred_hgb)
r2_hgb = r2_score(y_test, y_pred_hgb)

# Menyimpan hasil evaluasi ke dalam DataFrame
hgb_regression_results = pd.DataFrame({
    "Model": ["HistGradientBoostingRegressor"],
    "Mean Squared Error": [mse_hgb],
    "R^2 Score": [r2_hgb],
})

# Menampilkan hasil evaluasi regresi
print("\n", hgb_regression_results)
# Out:
#                             Model  Mean Squared Error  R^2 Score
# 0  HistGradientBoostingRegressor            0.399827   0.706624

# %%
print(X.columns)
# Out:
# Index(['Brand Name', 'Display Type', 'Backlight Technology Type',
#        'Diagonal Viewable Screen Size (in.)', 'Resolution Format',
#        'High Contrast Ratio (HCR) Display', 'Physical Data Ports Available',
#        'Ethernet Supported', 'Low Power Wireless Technologies Supported',
#        'Features', 'Automatic Brightness Control', 'Auto Brightness'],
#       dtype='object')

# %% [markdown]
# #### Menyimpan Model dengan akurasi tertinggi sebagai Pickel ####

# %%
import pickle

# Path direktori untuk menyimpan model yang sudah ada
model_path = '../../../app/models-pickle/house-energy/televisions.pkl'

# Simpan model ke file .pkl
with open(model_path, 'wb') as file:
    pickle.dump(rf_regressor, file)

print(f'Model disimpan ke {model_path}')
# Out:
# Model disimpan ke ../../../app/models-pickle/house-energy/televisions.pkl
